# %%
import pandas as pd

# %% [markdown]
# ## dropna & fillna

# %%
csv1 = pd.read_csv('test1.csv')
csv1
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %% [markdown]
# - dropping missing data row

# %%
csv1.dropna()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# 5      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %% [markdown]
# - dropping missing column data

# %%
csv1.dropna(axis=1)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %% [markdown]
# - removing all blank field using dropna(how='any')

# %%
csv2 = pd.read_csv('test2.csv')
csv2.dropna(how='any')
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 5      2021.0                     Level 1                99999
# 6      2021.0                     Level 1                99999
# 7      2021.0                     Level 1                99999
# 8      2021.0                     Level 1                99999
# 9      2021.0                     Level 1                99999
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 5                  All industries  Dollars (millions)           H09
# 6                  All industries  Dollars (millions)           H10
# ...

# %% [markdown]
# - removing a special row with no value and filling all other rows missing only one value with NaN

# %%
csv2.dropna(how='all')
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021.0                     Level 1                99999
# 1         NaN                     Level 1                99999
# 3         NaN                     Level 1                99999
# 4      2021.0                     Level 1                99999
# 5      2021.0                     Level 1                99999
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries                 NaN           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %% [markdown]
# - removing any particular field NaN value using dropna subset parameter

# %%
csv2.dropna(subset=['Year'])
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021.0                     Level 1                99999
# 4      2021.0                     Level 1                99999
# 5      2021.0                     Level 1                99999
# 6      2021.0                     Level 1                99999
# 7      2021.0                     Level 1                99999
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries                 NaN           H01
# 4                             NaN  Dollars (millions)           H08
# ...

# %% [markdown]
# - removing all NaN values and creating a new database using dropna inplace attribute

# %%
csv2.dropna(inplace=True)
csv2
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 5      2021.0                     Level 1                99999
# 6      2021.0                     Level 1                99999
# 7      2021.0                     Level 1                99999
# 8      2021.0                     Level 1                99999
# 9      2021.0                     Level 1                99999
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 5                  All industries  Dollars (millions)           H09
# 6                  All industries  Dollars (millions)           H10
# ...

# %% [markdown]
# - thresh attribute of dropna => it is used when we want to remove a row having (thresh=n) NaN value (not upper than n)

# %%
csv3 = pd.read_csv('test2.csv')
csv3.dropna(thresh=2)
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021.0                     Level 1                99999
# 1         NaN                     Level 1                99999
# 3         NaN                     Level 1                99999
# 4      2021.0                     Level 1                99999
# 5      2021.0                     Level 1                99999
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries                 NaN           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %% [markdown]
# - filling NaN values

# %%
csv3.fillna('Python')
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021.0                     Level 1                99999
# 1      Python                     Level 1                99999
# 2      Python                      Python               Python
# 3      Python                     Level 1                99999
# 4      2021.0                     Level 1                99999
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries              Python           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %% [markdown]
# - filling a particular data in a particular column

# %%
csv3.fillna({'Year':'Java','Value':500000})
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021.0                     Level 1                99999
# 1        Java                     Level 1                99999
# 2        Java                         NaN                  NaN
# 3        Java                     Level 1                99999
# 4      2021.0                     Level 1                99999
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries                 NaN           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %% [markdown]
# - if we want to fill NaN with its forward occuring data then we use fillna(method='ffill')
# - if we want to fill NaN with its fillna(method='bfill')

# %%
csv3.fillna(method='ffill')
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021.0                     Level 1                99999
# 1      2021.0                     Level 1                99999
# 2      2021.0                     Level 1                99999
# 3      2021.0                     Level 1                99999
# 4      2021.0                     Level 1                99999
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries                 NaN           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
csv3.fillna(method='bfill')
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021.0                     Level 1                99999
# 1      2021.0                     Level 1                99999
# 2      2021.0                     Level 1                99999
# 3      2021.0                     Level 1                99999
# 4      2021.0                     Level 1                99999
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
# filling using axis
csv3.fillna(method='bfill',axis=1)
# Out:
#           Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0       2021.0                     Level 1                99999
# 1      Level 1                     Level 1                99999
# 2          NaN                         NaN                  NaN
# 3      Level 1                     Level 1                99999
# 4       2021.0                     Level 1                99999
# ...        ...                         ...                  ...
# 41710   2013.0                     Level 3                 ZZ11
# 41711   2013.0                     Level 3                 ZZ11
# 41712   2013.0                     Level 3                 ZZ11
# 41713   2013.0                     Level 3                 ZZ11
# 41714   2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries                 H01           H01
# ...

# %%
csv3.fillna(method='ffill',axis=1)
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021.0                     Level 1                99999
# 1         NaN                     Level 1                99999
# 2         NaN                         NaN                  NaN
# 3         NaN                     Level 1                99999
# 4      2021.0                     Level 1                99999
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries      All industries           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %% [markdown]
# - using inplace attribute of fillna

# %%
csv3.fillna(12,inplace=True)
csv3
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021.0                     Level 1                99999
# 1        12.0                     Level 1                99999
# 2        12.0                          12                   12
# 3        12.0                     Level 1                99999
# 4      2021.0                     Level 1                99999
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries                  12           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %% [markdown]
# - filling data upto a given limit of rows

# %%
csv4 = pd.read_csv('test2.csv')
csv4.fillna('Python',limit=2)
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021.0                     Level 1                99999
# 1      Python                     Level 1                99999
# 2      Python                      Python               Python
# 3         NaN                     Level 1                99999
# 4      2021.0                     Level 1                99999
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries              Python           H01
# 1                  All industries  Dollars (millions)           H04
# ...
